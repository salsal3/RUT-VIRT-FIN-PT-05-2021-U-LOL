# %% [markdown]
# ### Import Libraries and Dependencies

# %%
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ### Read CSV as Pandas DataFrame

# %%
# Read in csv
csv_path = Path("G:/Users/Saru/Desktop/Bootcamp/RUT-VIRT-FIN-PT-05-2021-U-LOL/01-Activities/03-Python-Pandas/3/03-Stu_Sorting/Resources/tsla_google_finance.csv")
tsla_df = pd.read_csv(csv_path)
tsla_df.head()
# Out:
#        Date   Close
# 0  11/13/18  338.73
# 1  11/14/18  344.00
# 2  11/15/18  348.44
# 3  11/16/18  354.31
# 4  11/19/18  353.47

# %% [markdown]
# ### Index Data by `Date`

# %%
# Set `Date` as index
tsla_df = tsla_df.set_index('Date')
tsla_df.head()
# Out:
#            Close
# Date
# 11/13/18  338.73
# 11/14/18  344.00
# 11/15/18  348.44
# 11/16/18  354.31
# 11/19/18  353.47

# %% [markdown]
# ### Assess and Clean Data

# %%
# Check for nulls
tsla_df.isnull().mean() * 100
tsla_df.isnull().sum()

# Drop missing values
tsla_df = tsla_df.dropna()

# Validate no more missing values
tsla_df.isnull().sum()
tsla_df.head()
# Out:
#            Close
# Date
# 11/13/18  338.73
# 11/14/18  344.00
# 11/15/18  348.44
# 11/16/18  354.31
# 11/19/18  353.47

# %% [markdown]
# ### Calculate Daily Returns

# %%
# Calculate daily returns
tsla_daily_returns = tsla_df.pct_change()
tsla_daily_returns.head()
# Out:
#              Close
# Date
# 11/13/18       NaN
# 11/14/18  0.015558
# 11/15/18  0.012907
# 11/16/18  0.016847
# 11/19/18 -0.002371

# %% [markdown]
# ### Sort the DataFrame by `Close` to Get Records with Top Daily Returns

# %%
# Sort data by `Close` in descending order
tsla_top_changes = tsla_daily_returns.sort_values("Close", ascending=False)
tsla_top_changes.head()
# Out:
#              Close
# Date
# 12/26/18  0.103930
# 11/26/18  0.061903
# 1/4/19    0.057697
# 2/27/19   0.056671
# 12/28/18  0.056116

# %% [markdown]
# ### Slice Out 5 Records

# %%
# Slice out top 5
tsla_top_five = tsla_top_changes.iloc[:5]
tsla_top_five
# Out:
#              Close
# Date
# 12/26/18  0.103930
# 11/26/18  0.061903
# 1/4/19    0.057697
# 2/27/19   0.056671
# 12/28/18  0.056116

# %% [markdown]
# ### Plot Top 5 Performing Days for TSLA Daily Returns

# %%
# Plot top 5 performing days
tsla_top_five.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Alternatively, visualizing the returns as a bar chart:
tsla_top_five.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>
